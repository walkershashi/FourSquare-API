# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Installed')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.9.2         |   py36h45558ae_0         613 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.5               |   py36h830a2c2_0        10.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.9.2-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.7.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.5-py36h830a2c2_0
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.24.0-pyh9f0ad1d_0
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# cryptography-2.9.2   | 613 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# pandas-1.0.5         | 10.1 MB   | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installed

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7151482 -74.0156573

# %%
search_query = 'gym'
radius = 500
print(search_query + ' .... OK!')
# Out:
# gym .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=OECZ01BUCTDUDGR0YUA4VKHV1T4COOU5535O5OKPCJFEAU3F&client_secret=FETLWMYN0AT51PPEKTIYBFRENECKX1OBTUMNN5U2BHI3TH0K&ll=40.7151482,-74.0156573&v=20180604&query=gym&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f16da68f8ec05702a00a60a'},
#  'response': {'venues': [{'id': '4c8f73d24e95236ac70084ca',
#     'name': "Gym @ St. John's",
#     'location': {'address': '101 Murray St',
#      'lat': 40.71544647216797,
#      'lng': -74.01262664794922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71544647216797,
#        'lng': -74.01262664794922}],
#      'distance': 257,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['101 Murray St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4c8d0269f87e224bf4c13905',
#     'name': '89 Murray Gym',
#     'location': {'address': '89 Murray St',
#      'lat': 40.71562957763672,
#      'lng': -74.01211547851562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71562957763672,
#        'lng': -74.01211547851562}],
#      'distance': 303,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['89 Murray St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '5a595db6fe374079de98f6b5',
#     'name': 'Gym at Battery Park City Community Center',
#     'location': {'lat': 40.717914,
#      'lng': -74.013884,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.717914,
#        'lng': -74.013884}],
#      'distance': 342,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10282', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4cc1c0a667a3b1f7c29fca0e',
#     'name': 'Stuyvesant High School (3rd floor gym)',
#     'location': {'address': '345 Chambers St',
#      'lat': 40.7178840637207,
#      'lng': -74.01390838623047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7178840637207,
#        'lng': -74.01390838623047}],
#      'distance': 338,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['345 Chambers St',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4c0d68c8336220a1c2adca77',
#     'name': 'Millenium Hilton Gym',
#     'location': {'address': '55 Church St',
#      'lat': 40.71167268972019,
#      'lng': -74.01114851053406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71167268972019,
#        'lng': -74.01114851053406},
#       {'label': 'entrance', 'lat': 40.71116, 'lng': -74.010412}],
#      'distance': 542,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['55 Church St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '51bd9f1b498e5042c06df56a',
#     'name': 'The Gym @ The Riverhouse',
#     'location': {'address': '2 River Ter',
#      'lat': 40.71530124536505,
#      'lng': -74.01611965779145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71530124536505,
#        'lng': -74.01611965779145},
#       {'label': 'entrance', 'lat': 40.715672, 'lng': -74.016424}],
#      'distance': 42,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2 River Ter',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '5e164081e815270007658de5',
#     'name': 'Conrad Hilton Gym',
#     'location': {'address': '102 N End Ave',
#      'lat': 40.715090257774754,
#      'lng': -74.01556313037872,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715090257774754,
#        'lng': -74.01556313037872}],
#      'distance': 10,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['102 N End Ave',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '51780ffce4b0d0720c241e66',
#     'name': 'Tribeca Pointe Gym',
#     'location': {'address': '41 River Ter',
#      'lat': 40.71821212768555,
#      'lng': -74.01480865478516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71821212768555,
#        'lng': -74.01480865478516}],
#      'distance': 348,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['41 River Ter',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '53a0feb2498ea185a5cde9df',
#     'name': 'Liberty Green Gym',
#     'location': {'address': '300 N End Ave',
#      'crossStreet': 'Warren Street',
#      'lat': 40.71645702793296,
#      'lng': -74.01409655561106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71645702793296,
#        'lng': -74.01409655561106}],
#      'distance': 196,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['300 N End Ave (Warren Street)',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4e35ca636284ea7e110467c2',
#     'name': 'Gym @ Verdesian',
#     'location': {'address': '211 N End Ave',
#      'lat': 40.716132590223566,
#      'lng': -74.01459106559241,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.716132590223566,
#        'lng': -74.01459106559241}],
#      'distance': 141,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['211 N End Ave',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4f48fd45e4b052593ad63c9c',
#     'name': 'Tribeca Green Gym',
#     'location': {'address': 'North End Ave',
#      'crossStreet': 'Warren',
#      'lat': 40.716842841635966,
#      'lng': -74.01460040617347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.716842841635966,
#        'lng': -74.01460040617347}],
#      'distance': 208,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['North End Ave (Warren)',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4cb8d63490c9a143911783d6',
#     'name': '200 West Gym',
#     'location': {'address': '200 West St',
#      'crossStreet': 'Vessy St',
#      'lat': 40.71476291984364,
#      'lng': -74.01349546207545,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71476291984364,
#        'lng': -74.01349546207545}],
#      'distance': 187,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 West St (Vessy St)',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4c3b4b7ce927b7132a5d5eb2',
#     'name': 'Liberty Luxe Gym',
#     'location': {'address': '200 N End Ave',
#      'lat': 40.71598491463425,
#      'lng': -74.01437634622152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71598491463425,
#        'lng': -74.01437634622152}],
#      'distance': 142,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 N End Ave',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '50eb428be4b036eb62a4cfd5',
#     'name': 'My Gym',
#     'location': {'lat': 40.7159423828125,
#      'lng': -74.01416015625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7159423828125,
#        'lng': -74.01416015625}],
#      'distance': 154,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10007', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '5e13b94d18861d0008919e67',
#     'name': 'Amex Gym',
#     'location': {'lat': 40.714054,
#      'lng': -74.014463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714054,
#        'lng': -74.014463}],
#      'distance': 158,
#      'postalCode': '10281',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10281', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '50fc5857e4b03c6cbb1d650d',
#     'name': 'Gym at WFC 2',
#     'location': {'lat': 40.71292412264361,
#      'lng': -74.01600305325574,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71292412264361,
#        'lng': -74.01600305325574}],
#      'distance': 249,
#      'postalCode': '10280',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10280', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4bc21076920eb7131f901b2c',
#     'name': '22 River Terrace Gym',
#     'location': {'address': '22 River Ter',
#      'lat': 40.71720969207093,
#      'lng': -74.0152927100357,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71720969207093,
#        'lng': -74.0152927100357}],
#      'distance': 231,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['22 River Ter',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '51506e85e4b03aaa032a16da',
#     'name': 'NY Mercantile Gym',
#     'location': {'lat': 40.7146955075536,
#      'lng': -74.0173343010969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7146955075536,
#        'lng': -74.0173343010969}],
#      'distance': 150,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '50fdd8e9e4b0c9eebd272ee9',
#     'name': "Gym @ St. John's",
#     'location': {'address': '101 Murray St',
#      'crossStreet': 'Greenwich',
#      'lat': 40.71544647216797,
#      'lng': -74.01262664794922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71544647216797,
#        'lng': -74.01262664794922}],
#      'distance': 257,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['101 Murray St (Greenwich)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '5811772438fa253edca809ea',
#     'name': 'River & Warren Gym',
#     'location': {'address': '212 Warren St',
#      'lat': 40.717273,
#      'lng': -74.015828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.717273,
#        'lng': -74.015828}],
#      'distance': 236,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['212 Warren St',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4e7541cad1643f93b1daf611',
#     'name': 'Warren Gym',
#     'location': {'lat': 40.71551074106577,
#      'lng': -74.01285851719669,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71551074106577,
#        'lng': -74.01285851719669}],
#      'distance': 239,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4f31d588e4b057434ce95ef2',
#     'name': 'Gym@marriot',
#     'location': {'address': 'Marriot',
#      'lat': 40.71160572694045,
#      'lng': -74.01468901072462,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71160572694045,
#        'lng': -74.01468901072462}],
#      'distance': 402,
#      'postalCode': '10280',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Marriot', 'New York, NY 10280', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4d7708cd926a6dcb02d64200',
#     'name': '2 River Terrace Fitness Center',
#     'location': {'address': '2 River Ter',
#      'crossStreet': 'Murray',
#      'lat': 40.715111007518225,
#      'lng': -74.01598568776276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715111007518225,
#        'lng': -74.01598568776276}],
#      'distance': 28,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2 River Ter (Murray)',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4cc87f59786e468804978e09',
#     'name': 'American Express Fitness Center',
#     'location': {'address': '4th Fl. 3 World Financial Center',
#      'lat': 40.71375226685945,
#      'lng': -74.01427586011309,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71375226685945,
#        'lng': -74.01427586011309}],
#      'distance': 194,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4th Fl. 3 World Financial Center',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '4b927dbcf964a520d1fd33e3',
#     'name': 'Solaire',
#     'location': {'address': '20 River Ter',
#      'crossStreet': 'Murray',
#      'lat': 40.71676910358814,
#      'lng': -74.01550600945424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71676910358814,
#        'lng': -74.01550600945424}],
#      'distance': 180,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['20 River Ter (Murray)',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595333616',
#     'hasPerk': False},
#    {'id': '50ddf0dbe4b0929c14560f46',
#     'name': 'The Club at Gateway',
#     'location': {'address': '375 S End Ave',
#      'lat': 40.711349545118146,
#      'lng': -74.0178961185848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.711349545118146,
#        'lng': -74.0178961185848}],
#      'distance': 463,
#      'postalCode': '10280',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['375 S End Ave',
#       'New York, NY 10280',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '80142872'},
#     'referralId': 'v-1595333616',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
venues_df = json_normalize(venues)
venues_df.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                                       name  \
# 0  4c8f73d24e95236ac70084ca                           Gym @ St. John's
# 1  4c8d0269f87e224bf4c13905                              89 Murray Gym
# 2  5a595db6fe374079de98f6b5  Gym at Battery Park City Community Center
# 3  4cc1c0a667a3b1f7c29fca0e     Stuyvesant High School (3rd floor gym)
# 4  4c0d68c8336220a1c2adca77                       Millenium Hilton Gym
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1595333616    False
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1595333616    False
# 2  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1595333616    False
# 3  [{'id': '4bf58dd8d48988d1a7941735', 'name': 'C...  v-1595333616    False
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1595333616    False
#
#   location.address  location.lat  location.lng  \
# 0    101 Murray St     40.715446    -74.012627
# 1     89 Murray St     40.715630    -74.012115
# 2              NaN     40.717914    -74.013884
# 3  345 Chambers St     40.717884    -74.013908
# 4     55 Church St     40.711673    -74.011149
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.71544647216797...                257
# 1  [{'label': 'display', 'lat': 40.71562957763672...                303
# 2  [{'label': 'display', 'lat': 40.717914, 'lng':...                342
# 3  [{'label': 'display', 'lat': 40.7178840637207,...                338
# 4  [{'label': 'display', 'lat': 40.71167268972019...                542
#
#   location.postalCode location.cc location.city location.state  \
# 0               10007          US      New York             NY
# 1               10007          US      New York             NY
# 2               10282          US      New York             NY
# 3               10282          US      New York             NY
# 4               10007          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [101 Murray St, New York, NY 10007, United Sta...
# 1    United States  [89 Murray St, New York, NY 10007, United States]
# 2    United States                [New York, NY 10282, United States]
# 3    United States  [345 Chambers St, New York, NY 10282, United S...
# 4    United States  [55 Church St, New York, NY 10007, United States]
#
#   location.crossStreet venuePage.id
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN

# %%
venues_id = venues_df[['id']]
venues_df = venues_df.drop(['id', 'referralId', 'hasPerk', 'location.labeledLatLngs', 'location.cc', 'location.crossStreet', 'venuePage.id'],axis = 1)
venues_df = pd.concat([venues_df, venues_id], axis = 1)

venues_df.head()
# Out:
#                                         name  \
# 0                           Gym @ St. John's
# 1                              89 Murray Gym
# 2  Gym at Battery Park City Community Center
# 3     Stuyvesant High School (3rd floor gym)
# 4                       Millenium Hilton Gym
#
#                                           categories location.address  \
# 0  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    101 Murray St
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...     89 Murray St
# 2  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...              NaN
# 3  [{'id': '4bf58dd8d48988d1a7941735', 'name': 'C...  345 Chambers St
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...     55 Church St
#
#    location.lat  location.lng  location.distance location.postalCode  \
# 0     40.715446    -74.012627                257               10007
# 1     40.715630    -74.012115                303               10007
# 2     40.717914    -74.013884                342               10282
# 3     40.717884    -74.013908                338               10282
# 4     40.711673    -74.011149                542               10007
#
#   location.city location.state location.country  \
# 0      New York             NY    United States
# 1      New York             NY    United States
# 2      New York             NY    United States
# 3      New York             NY    United States
# 4      New York             NY    United States
#
#                            location.formattedAddress                        id
# 0  [101 Murray St, New York, NY 10007, United Sta...  4c8f73d24e95236ac70084ca
# 1  [89 Murray St, New York, NY 10007, United States]  4c8d0269f87e224bf4c13905
# 2                [New York, NY 10282, United States]  5a595db6fe374079de98f6b5
# 3  [345 Chambers St, New York, NY 10282, United S...  4cc1c0a667a3b1f7c29fca0e
# 4  [55 Church St, New York, NY 10007, United States]  4c0d68c8336220a1c2adca77

# %%
filtered_columns = ['name', 'categories'] + [col for col in venues_df.columns if col.startswith('location.')] + ['id']
columns = [column.split('.')[-1] for column in filtered_columns]
        
venues_df.columns = columns

for i in range(venues_df.shape[0]):
    venues_df['categories'][i] = venues_df['categories'][i][0]['name']

venues_df.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                         name            categories  \
# 0                           Gym @ St. John's  Gym / Fitness Center
# 1                              89 Murray Gym                   Gym
# 2  Gym at Battery Park City Community Center  Gym / Fitness Center
# 3     Stuyvesant High School (3rd floor gym)       College Library
# 4                       Millenium Hilton Gym                   Gym
#
#            address        lat        lng  distance postalCode      city state  \
# 0    101 Murray St  40.715446 -74.012627       257      10007  New York    NY
# 1     89 Murray St  40.715630 -74.012115       303      10007  New York    NY
# 2              NaN  40.717914 -74.013884       342      10282  New York    NY
# 3  345 Chambers St  40.717884 -74.013908       338      10282  New York    NY
# 4     55 Church St  40.711673 -74.011149       542      10007  New York    NY
#
#          country                                   formattedAddress  \
# 0  United States  [101 Murray St, New York, NY 10007, United Sta...
# 1  United States  [89 Murray St, New York, NY 10007, United States]
# 2  United States                [New York, NY 10282, United States]
# 3  United States  [345 Chambers St, New York, NY 10282, United S...
# 4  United States  [55 Church St, New York, NY 10007, United States]
#
#                          id
# 0  4c8f73d24e95236ac70084ca
# 1  4c8d0269f87e224bf4c13905
# 2  5a595db6fe374079de98f6b5
# 3  4cc1c0a667a3b1f7c29fca0e
# 4  4c0d68c8336220a1c2adca77

# %%
venues_map = folium.Map(location = [latitude, longitude], zoom_start = 15)

folium.features.CircleMarker(
    [latitude, longitude],
    radius = 10,
    color = 'blue',
    popup = 'Your Location',
    fill = True,
    fill_color = 'blue',
    fill_opacity = 0.6
).add_to(venues_map)


venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for lat, lng, label in zip(venues_df.lat, venues_df.lng, venues_df.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius = 5,
        color = 'red',
        popup = label,
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.6
    ).add_to(venues_map)
    
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
